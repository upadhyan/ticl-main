# %%
import pandas as pd
import numpy as np

from ticl.evaluation.cd_plot_new.cd_plot_code import cd_evaluation
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore", FutureWarning)

# varies_over_time= ['XGBoost', 'RF', 'MLP', 'KNN', 'LogReg']

#validation_result_file = 'results/results_validation_for_paper_2024-05-16.csv'
#validation_result_file = 'results/results_validation_2024-05-20.csv'
validation_result_file = 'results/results_validation_2024-05-20.csv'
test_result_file = 'results/results_test_for_mothernet_paper_2024-05-21.csv'

#test_result_file = None

valid_results = pd.read_csv(validation_result_file, index_col=0)
rename_dict = {#'additive_Dclass_average_factorizedoutputTrue_w001_03_02_2024_02_21_10_epoch_420': 'additive class average factorized',
                                                      'additive_Dclass_average_02_29_2024_04_15_55_epoch_1050': 'additive_class_average',
                                                      'additive_1_gpu_02_14_2024_16_34_15': 'additive dense',
                                                   'mn_Dclass_average_03_25_2024_17_14_32_epoch_3970_ohe_ensemble_8': 'MotherNet',
                                                    'MotherNet': 'mothernet_old',
                                                     'additive_Dclass_average_multiclassmaxsteps3_multiclasstypesteps_03_04_2024_19_04_03_epoch_270': 'steps_prior',
                                                     #'baam_nfeatures_20_no_ensemble_e1520': 'GammaNet',
    'mothernet_ohe_ensemble_8_quantile_gpu_timing': 'MotherNet',
    'mn_categoricalfeaturep09_numfeaturessamplerdouble_sample_05_09_2024_23_39_30_epoch_1270_ohe_quantile_8': 'MotherNet',

    'batapfn_no_ensemble_e410': 'bi-attention TabPFN',
    'XGBoost': 'XGBoost$^\dag$',
    'KNN': 'KNN$^\dag$',
    'mlp_gpu2': 'MLP$^\ddag$',
    'resnet_gpu': 'ResNet$^\ddag$',
    'mn_categoricalfeaturep09_numfeaturessamplerdouble_sample_05_09_2024_23_39_30_epoch_1270_ohe_quantile_8_cpu_timing3': 'MotherNet (CPU)',
    #'ebm_default': 'EBM (interactions)',
    #'ebm_bins_main_effects': 'EBM (main effects)',
    'hyperfast_no_optimize_gpu': 'HyperFast no FT',
    'hyperfast_defaults_gpu' : 'HyperFast default',
    'hyperfast_tuning_gpu': 'HyperFast$^\ddag$',
    'LogReg': 'Logistic Regression$^\dag$',
     'RF': 'RandomForest$^\dag$',
    'mothernet_init_gd_no_learning_preprocess2': 'MotherNet NE',
    'mothernet_gd_gpu4': 'MotherNet FT$^\ddag$',
    'TabPFN (Hollmann)': 'TabPFN',
    "MotherNet": "MotherNet_old",
    
   # 'MLP-Distill': 'mlp_distill',
    #'MLP': 'MLP (60 min HPO)',
    'MLP': 'MLP_drop',
    'TabPFN (ours)': 'tabpfn_ours_hide'}
#valid_results.model.unique()
#valid_results['model'] = valid_results.model.replace({'hyperfast_defaults_cpu': 'hyperfast_defaults_gpu'}) ## HACCCKKK
valid_results['model'] = valid_results.model.replace(rename_dict)

valid_results = valid_results[valid_results.model != "hyperfast_no_optimize_cpu"]
valid_results = valid_results[~valid_results.model.str.contains('_')]
all_models = valid_results.model.unique()

# %%
all_models
# Out:
# array(['KNN$^\\dag$', 'RandomForest$^\\dag$', 'XGBoost$^\\dag$',
#        'Logistic Regression$^\\dag$', 'MLP-Distill', 'TabPFN',
#        'HyperFast no FT', 'HyperFast default', 'MotherNet'], dtype=object)

# %%
if test_result_file:
    test_results = pd.read_csv(test_result_file, index_col=0)
    test_results['model'] = test_results.model.replace(rename_dict)
    test_results = test_results[~test_results.model.str.contains('_')]
    all_models = set(valid_results.model.unique()).union(set(test_results.model.unique()))

    print(test_results.model.unique())
    print(valid_results.model.unique())
    assert set(test_results.model.unique()) == set(valid_results.model.unique())
# Out:
# ['KNN$^\\dag$' 'RandomForest$^\\dag$' 'XGBoost$^\\dag$'
#  'Logistic Regression$^\\dag$' 'MLP-Distill' 'TabPFN' 'MotherNet NE'
#  'HyperFast no FT' 'HyperFast default' 'MotherNet' 'MotherNet (CPU)'
#  'HyperFast$^\\ddag$' 'MLP$^\\ddag$' 'ResNet$^\\ddag$'
#  'MotherNet FT$^\\ddag$']
# ['KNN$^\\dag$' 'RandomForest$^\\dag$' 'XGBoost$^\\dag$'
#  'Logistic Regression$^\\dag$' 'MLP-Distill' 'TabPFN' 'HyperFast no FT'
#  'HyperFast default' 'MotherNet']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 9
#       7 print(test_results.model.unique())
#       8 print(valid_results.model.unique())
# ----> 9 assert set(test_results.model.unique()) == set(valid_results.model.unique())
#
# AssertionError:

# %%
color_palette = sns.color_palette(n_colors=len(all_models))
color_mapping = dict(zip(all_models, color_palette))

# %%
def get_best_over_time(results):
    max_time_per_dataset_model = results.groupby(["dataset", "model"])["max_time"].max().rename('max_time_overall')
    average_over_splits = results.groupby(["dataset", "model", "max_time"])[["mean_metric", "fit_time", "inference_time"]].mean()
    joined_with_max_time = average_over_splits.join(max_time_per_dataset_model).reset_index()
    return joined_with_max_time[joined_with_max_time.max_time == joined_with_max_time.max_time_overall]

# %%
plt.figure(figsize=(8, 4), dpi=300)
combined_best_valid = get_best_over_time(valid_results)
pivoted_for_cd = combined_best_valid.pivot(index="dataset", columns="model", values="mean_metric")
_ = cd_evaluation(pivoted_for_cd, maximize_metric=True, ax=plt.gca())
plt.savefig("../figures/cd_diagram_validation.pdf", bbox_inches="tight")

# %%
def hide_for_plots(df):
    #hidden_models = ["MotherNet (CPU)", 'MotherNet (no baggging)','MotherNet plus Gradient Descent$^\\ddag$']
    hidden_models = ["MotherNet (CPU)"]
    return df[~df.model.isin(hidden_models)]

# %%
if test_result_file:
    plt.figure(figsize=(8, 4), dpi=300)
    combined_best_test = get_best_over_time(hide_for_plots(test_results))
    #combined_best_test = get_best_over_time(test_results)

    
    pivoted_for_cd_test = combined_best_test.pivot(index="dataset", columns="model", values="mean_metric")
    _ = cd_evaluation(pivoted_for_cd_test, maximize_metric=True, ax=plt.gca())
    plt.savefig("../figures/cd_diagram_test.pdf", bbox_inches="tight")

# %%
# combined_best_test_norms = combined_best_test.merge(combined_best_test.groupby("dataset").mean_metric.max().rename("max_auc"), left_on="dataset", right_index=True)
# combined_best_test_norms = combined_best_test_norms.merge(combined_best_test.groupby("dataset").mean_metric.min().rename("min_auc"), left_on="dataset", right_index=True)
# combined_best_test_norms['Normalized ROC AUC'] = (combined_best_test_norms.mean_metric - combined_best_test_norms.min_auc) / (combined_best_test_norms.max_auc - combined_best_test_norms.min_auc)

# %%
def get_varies_over_time(results):
    times = results.groupby(["dataset", "model", "split"]).size().unstack("model").reset_index(drop=True).apply(pd.unique)
    assert len(times) == 1
    times = times.T
    return times.index[times[0] > 1]

def compare_splits(results):
    varies_over_time = get_varies_over_time(results)
    compare_splits_over_time = results.groupby(["model", "split", "max_time"])[['mean_metric', 'fit_time', 'inference_time']].mean().reset_index()
    compare_splits_varies = compare_splits_over_time[compare_splits_over_time.model.isin(varies_over_time)]
    compare_splits_fixed = compare_splits_over_time[~compare_splits_over_time.model.isin(varies_over_time)]
    compare_splits_varies_last = compare_splits_varies[compare_splits_varies.max_time == compare_splits_varies.max_time.max()]
    return compare_splits_over_time, pd.concat([compare_splits_fixed, compare_splits_varies_last])

# %%
compare_splits_over_time_valid, compare_splits_valid = compare_splits(valid_results)
if test_result_file:
    compare_splits_over_time_test, compare_splits_test = compare_splits(test_results)

# %%
compare_splits_test.model.unique()
# Out:
# array(['HyperFast default', 'HyperFast no FT', 'HyperFast$^\\ddag$',
#        'MLP$^\\ddag$', 'MLP-Distill', 'MotherNet', 'MotherNet (CPU)',
#        'MotherNet FT$^\\ddag$', 'MotherNet NE', 'ResNet$^\\ddag$',
#        'TabPFN', 'KNN$^\\dag$', 'Logistic Regression$^\\dag$',
#        'RandomForest$^\\dag$', 'XGBoost$^\\dag$'], dtype=object)

# %%
compare_splits_test
# Out:
#                  model  split  max_time  mean_metric   fit_time  \
# 0    HyperFast default      1         1     0.871031  25.921448
# 1    HyperFast default      2         1     0.874253  25.936376
# 2    HyperFast default      3         1     0.872247  25.944714
# 3    HyperFast default      4         1     0.871181  26.003774
# 4    HyperFast default      5         1     0.876239  25.994218
# ..                 ...    ...       ...          ...        ...
# 166     XGBoost$^\dag$      1      3600     0.892359   6.723667
# 173     XGBoost$^\dag$      2      3600     0.894503   4.535582
# 180     XGBoost$^\dag$      3      3600     0.886975   5.508178
# 187     XGBoost$^\dag$      4      3600     0.891691   4.674549
# 194     XGBoost$^\dag$      5      3600     0.888723   3.119718
#
#      inference_time
# 0          0.045736
# 1          0.045678
# 2          0.045705
# 3          0.045747
# 4          0.045641
# ..              ...
# 166        0.033228
# 173        0.023492
# 180        0.026886
# 187        0.016897
# 194        0.017532
#
# [75 rows x 6 columns]

# %%
plt.figure(figsize=(6, 4))
compare_splits_valid = compare_splits_valid[~compare_splits_valid.model.isin(["KNN", "Neural Network"])]
order = compare_splits_valid.groupby("model").mean("mean_metric").sort_values("mean_metric").index
sns.boxplot(data=compare_splits_valid, y="model", x="mean_metric", order=order, ax=plt.gca(), palette=color_mapping)
#sns.boxplot(data=compare_splits_valid, y="model", x="mean_metric",order=order, ax=plt.gca(), hue="model")

plt.xlabel("Average ROC AUC")
plt.savefig("../figures/mean_roc_auc_validation.pdf", dpi=300, bbox_inches="tight")

# %%
compare_splits_test.model.unique()
# Out:
# array(['HyperFast default', 'HyperFast no FT', 'HyperFast$^\\ddag$',
#        'MLP$^\\ddag$', 'MLP-Distill', 'MotherNet', 'MotherNet (CPU)',
#        'MotherNet FT$^\\ddag$', 'MotherNet NE', 'ResNet$^\\ddag$',
#        'TabPFN', 'KNN$^\\dag$', 'Logistic Regression$^\\dag$',
#        'RandomForest$^\\dag$', 'XGBoost$^\\dag$'], dtype=object)

# %%
hide_for_plots(compare_splits_test_no_cpu).model.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 hide_for_plots(compare_splits_test_no_cpu).model.unique()
#
# NameError: name 'compare_splits_test_no_cpu' is not defined

# %%
if test_result_file:
    plt.figure(figsize=(6, 4))
    compare_splits_test_no_cpu = hide_for_plots(compare_splits_test)
    order = compare_splits_test_no_cpu.groupby("model").mean("mean_metric").sort_values("mean_metric").index
    sns.boxplot(data=compare_splits_test_no_cpu, y="model", x="mean_metric", order=order, ax=plt.gca(), palette=color_mapping)
    plt.xlabel("Average ROC AUC")
    plt.savefig("../figures/mean_roc_auc_test.pdf", dpi=300, bbox_inches="tight")

# %%
def normalize_metric(results):
    dataset_min_max = results.groupby("dataset").mean_metric.agg(["min", "max"])
    results_normalized = results.merge(dataset_min_max, on="dataset")
    results_normalized['mean_metric'] = (results_normalized['mean_metric'] - results_normalized['min']) / (results_normalized['max'] - results_normalized['min'])
    return results_normalized

# %%
compare_splits_over_time_valid_normalized, compare_splits_valid_normalized = compare_splits(normalize_metric(valid_results))
if test_result_file:
    compare_splits_over_time_test_normalized, compare_splits_test_normalized = compare_splits(normalize_metric(test_results))

# %%
compare_splits_test_normalized
# Out:
#                  model  split  max_time  mean_metric   fit_time  \
# 0    HyperFast default      1         1     0.665739  25.921448
# 1    HyperFast default      2         1     0.701237  25.936376
# 2    HyperFast default      3         1     0.658257  25.944714
# 3    HyperFast default      4         1     0.678194  26.003774
# 4    HyperFast default      5         1     0.702729  25.994218
# ..                 ...    ...       ...          ...        ...
# 166     XGBoost$^\dag$      1      3600     0.817559   6.723667
# 173     XGBoost$^\dag$      2      3600     0.835423   4.535582
# 180     XGBoost$^\dag$      3      3600     0.762554   5.508178
# 187     XGBoost$^\dag$      4      3600     0.807341   4.674549
# 194     XGBoost$^\dag$      5      3600     0.795048   3.119718
#
#      inference_time
# 0          0.045736
# 1          0.045678
# 2          0.045705
# 3          0.045747
# 4          0.045641
# ..              ...
# 166        0.033228
# 173        0.023492
# 180        0.026886
# 187        0.016897
# 194        0.017532
#
# [75 rows x 6 columns]

# %%
compare_splits_test_normalized.to_csv("test_auc_normalized_per_split_gams.csv")

# %%
if test_result_file:
    plt.figure(figsize=(6, 4))
    compare_splits_test_normalized_no_cpu = hide_for_plots(compare_splits_test)
    order = compare_splits_test_normalized_no_cpu.groupby("model").mean("mean_metric").sort_values("mean_metric").index
    sns.boxplot(data=compare_splits_test_normalized_no_cpu, y="model", x="mean_metric", order=order, ax=plt.gca(), palette=color_mapping)
    plt.xlabel("Average ROC AUC (normalized)", loc="right")
    plt.savefig("../figures/mean_roc_auc_test_normalized.pdf", dpi=300, bbox_inches="tight")

# %%
# table.drop(index=["mothernet_old", "mlp_distill", 'KNN']).rename({'mn_Dclass_average_03_25_2024_17_14_32_epoch_2910_ohe_ensemble_8': 'MotherNet'})

# %%
plt.figure(figsize=(6, 4))
compare_splits_valid_normalized = compare_splits_valid_normalized[~compare_splits_valid_normalized.model.isin(["KNN", "Neural Network"])]
order = compare_splits_valid_normalized.groupby("model").mean("mean_metric").sort_values("mean_metric").index
sns.boxplot(data=compare_splits_valid_normalized, y="model", x="mean_metric", order=order, ax=plt.gca(), palette=color_mapping)
#sns.boxplot(data=compare_splits_valid_normalized, y="model", x="mean_metric", order=order, ax=plt.gca(), hue='model')

plt.xlabel("Average ROC AUC (normalized)", loc="right")
plt.savefig("../figures/mean_roc_auc_valid_normalized.pdf", dpi=300, bbox_inches="tight")

# %%
compare_splits_test_normalized.model.unique()
# Out:
# array(['HyperFast default', 'HyperFast no FT', 'HyperFast$^\\ddag$',
#        'MLP$^\\ddag$', 'MLP-Distill', 'MotherNet', 'MotherNet (CPU)',
#        'MotherNet FT$^\\ddag$', 'MotherNet NE', 'ResNet$^\\ddag$',
#        'TabPFN', 'KNN$^\\dag$', 'Logistic Regression$^\\dag$',
#        'RandomForest$^\\dag$', 'XGBoost$^\\dag$'], dtype=object)

# %%
def make_score_table(split_df, metric_name):
    split_df_groupby = split_df.rename(columns={'mean_metric': metric_name}).groupby("model")[['fit_time', 'inference_time', metric_name]]
    split_df_mean = split_df_groupby.mean()
    split_df_std = split_df_groupby.std()
    return split_df_mean.merge(split_df_std, on="model", suffixes=("", " std"))

# %%
compare_splits_test
# Out:
#                  model  split  max_time  mean_metric   fit_time  \
# 0    HyperFast default      1         1     0.871031  25.921448
# 1    HyperFast default      2         1     0.874253  25.936376
# 2    HyperFast default      3         1     0.872247  25.944714
# 3    HyperFast default      4         1     0.871181  26.003774
# 4    HyperFast default      5         1     0.876239  25.994218
# ..                 ...    ...       ...          ...        ...
# 166     XGBoost$^\dag$      1      3600     0.892359   6.723667
# 173     XGBoost$^\dag$      2      3600     0.894503   4.535582
# 180     XGBoost$^\dag$      3      3600     0.886975   5.508178
# 187     XGBoost$^\dag$      4      3600     0.891691   4.674549
# 194     XGBoost$^\dag$      5      3600     0.888723   3.119718
#
#      inference_time
# 0          0.045736
# 1          0.045678
# 2          0.045705
# 3          0.045747
# 4          0.045641
# ..              ...
# 166        0.033228
# 173        0.023492
# 180        0.026886
# 187        0.016897
# 194        0.017532
#
# [75 rows x 6 columns]

# %%
compare_splits_test_normalized
# Out:
#                  model  split  max_time  mean_metric   fit_time  \
# 0    HyperFast default      1         1     0.665739  25.921448
# 1    HyperFast default      2         1     0.701237  25.936376
# 2    HyperFast default      3         1     0.658257  25.944714
# 3    HyperFast default      4         1     0.678194  26.003774
# 4    HyperFast default      5         1     0.702729  25.994218
# ..                 ...    ...       ...          ...        ...
# 166     XGBoost$^\dag$      1      3600     0.817559   6.723667
# 173     XGBoost$^\dag$      2      3600     0.835423   4.535582
# 180     XGBoost$^\dag$      3      3600     0.762554   5.508178
# 187     XGBoost$^\dag$      4      3600     0.807341   4.674549
# 194     XGBoost$^\dag$      5      3600     0.795048   3.119718
#
#      inference_time
# 0          0.045736
# 1          0.045678
# 2          0.045705
# 3          0.045747
# 4          0.045641
# ..              ...
# 166        0.033228
# 173        0.023492
# 180        0.026886
# 187        0.016897
# 194        0.017532
#
# [75 rows x 6 columns]

# %%
normed_table = make_score_table(compare_splits_test_normalized, "Normalized ROC AUC")
unnormed_table = make_score_table(compare_splits_test, "ROC AUC")

# %%
pivoted_for_cd_test
# Out:
# model                             HyperFast default  HyperFast no FT  \
# dataset
# MiceProtein                                0.999975         0.988606
# analcatdata_authorship                     0.999931         0.999933
# analcatdata_dmft                           0.526849         0.554439
# balance-scale                              0.992595         0.885619
# banknote-authentication                    1.000000         0.984273
# blood-transfusion-service-center           0.714981         0.739178
# breast-w                                   0.992054         0.992034
# car                                        0.994874         0.921184
# climate-model-simulation-crashes           0.908414         0.914109
# cmc                                        0.665414         0.672631
# credit-approval                            0.899582         0.924878
# credit-g                                   0.749241         0.771899
# cylinder-bands                             0.815781         0.801273
# diabetes                                   0.795134         0.819651
# dresses-sales                              0.554970         0.576730
# eucalyptus                                 0.873302         0.806779
# ilpd                                       0.710749         0.721144
# kc2                                        0.735030         0.812112
# mfeat-fourier                              0.976509         0.963048
# mfeat-karhunen                             0.997892         0.995219
# mfeat-morphological                        0.967094         0.956976
# mfeat-zernike                              0.979591         0.972718
# pc1                                        0.824034         0.783036
# pc3                                        0.794284         0.793712
# pc4                                        0.901929         0.863957
# qsar-biodeg                                0.923709         0.903840
# steel-plates-fault                         0.955216         0.944202
# tic-tac-toe                                0.991561         0.807209
# vehicle                                    0.954020         0.908678
# wdbc                                       0.994989         0.988299
#
# model                             HyperFast$^\ddag$  KNN$^\dag$  \
# dataset
# MiceProtein                                0.999979    0.997160
# analcatdata_authorship                     0.999930    0.999763
# analcatdata_dmft                           0.560911    0.546662
# balance-scale                              0.992852    0.885090
# banknote-authentication                    1.000000    0.999211
# blood-transfusion-service-center           0.732298    0.708473
# breast-w                                   0.990352    0.984045
# car                                        0.990115    0.915854
# climate-model-simulation-crashes           0.903066    0.848553
# cmc                                        0.692358    0.633549
# credit-approval                            0.925720    0.914295
# credit-g                                   0.759687    0.726149
# cylinder-bands                             0.812691    0.781100
# diabetes                                   0.812612    0.805992
# dresses-sales                              0.551978    0.555283
# eucalyptus                                 0.873917    0.798225
# ilpd                                       0.700813    0.645964
# kc2                                        0.802879    0.782070
# mfeat-fourier                              0.976811    0.970107
# mfeat-karhunen                             0.998039    0.993779
# mfeat-morphological                        0.966732    0.950986
# mfeat-zernike                              0.982327    0.976047
# pc1                                        0.824187    0.784165
# pc3                                        0.816029    0.752773
# pc4                                        0.896928    0.821749
# qsar-biodeg                                0.924881    0.891576
# steel-plates-fault                         0.954470    0.919987
# tic-tac-toe                                0.921289    0.986518
# vehicle                                    0.953994    0.880704
# wdbc                                       0.994275    0.990773
#
# model                             Logistic Regression$^\dag$  MLP$^\ddag$  \
# dataset
# MiceProtein                                         0.999254     0.999704
# analcatdata_authorship                              0.999965     0.999945
# analcatdata_dmft                                    0.569513     0.566935
# balance-scale                                       0.961861     0.994421
# banknote-authentication                             0.999728     1.000000
# blood-transfusion-service-center                    0.749845     0.733690
# breast-w                                            0.993937     0.991927
# car                                                 0.982618     0.995749
# climate-model-simulation-crashes                    0.932231     0.913469
# cmc                                                 0.681470     0.670426
# credit-approval                                     0.919708     0.917602
# credit-g                                            0.768323     0.764953
# cylinder-bands                                      0.821196     0.841040
# diabetes                                            0.839514     0.842510
# dresses-sales                                       0.573299     0.566131
# eucalyptus                                          0.896053     0.891982
# ilpd                                                0.739249     0.731243
# kc2                                                 0.826386     0.813542
# mfeat-fourier                                       0.977253     0.974658
# mfeat-karhunen                                      0.995499     0.995814
# mfeat-morphological                                 0.965621     0.965486
# mfeat-zernike                                       0.979642     0.981056
# pc1                                                 0.834567     0.799367
# pc3                                                 0.785223     0.800484
# pc4                                                 0.893722     0.895414
# qsar-biodeg                                         0.922223     0.920245
# steel-plates-fault                                  0.937981     0.950295
# tic-tac-toe                                         0.995771     0.995681
# vehicle                                             0.945371     0.956568
# wdbc                                                0.993668     0.990686
#
# model                             MLP-Distill  MotherNet  \
# dataset
# MiceProtein                          0.999800   0.998348
# analcatdata_authorship               0.999977   0.999990
# analcatdata_dmft                     0.576845   0.570724
# balance-scale                        0.992246   0.996780
# banknote-authentication              1.000000   1.000000
# blood-transfusion-service-center     0.757076   0.758114
# breast-w                             0.994349   0.993400
# car                                  0.985040   0.965375
# climate-model-simulation-crashes     0.911046   0.946996
# cmc                                  0.735373   0.722870
# credit-approval                      0.928207   0.928267
# credit-g                             0.774772   0.791420
# cylinder-bands                       0.810552   0.798265
# diabetes                             0.842692   0.847734
# dresses-sales                        0.535937   0.570375
# eucalyptus                           0.917685   0.923264
# ilpd                                 0.730987   0.729041
# kc2                                  0.838882   0.830413
# mfeat-fourier                        0.980709   0.972416
# mfeat-karhunen                       0.997722   0.994006
# mfeat-morphological                  0.967338   0.960224
# mfeat-zernike                        0.980874   0.976252
# pc1                                  0.853921   0.844746
# pc3                                  0.831391   0.814055
# pc4                                  0.932452   0.931495
# qsar-biodeg                          0.923665   0.925918
# steel-plates-fault                   0.955680   0.932319
# tic-tac-toe                          0.846881   0.995599
# vehicle                              0.960955   0.948552
# wdbc                                 0.994536   0.995335
#
# model                             MotherNet FT$^\ddag$  MotherNet NE  \
# dataset
# MiceProtein                                   0.995143      0.996382
# analcatdata_authorship                        0.999943      0.999949
# analcatdata_dmft                              0.547026      0.559468
# balance-scale                                 0.993361      0.993849
# banknote-authentication                       1.000000      1.000000
# blood-transfusion-service-center              0.757978      0.759891
# breast-w                                      0.993755      0.993516
# car                                           0.976905      0.969303
# climate-model-simulation-crashes              0.934504      0.943353
# cmc                                           0.707790      0.715368
# credit-approval                               0.926870      0.928687
# credit-g                                      0.786980      0.786832
# cylinder-bands                                0.802823      0.832111
# diabetes                                      0.831150      0.842373
# dresses-sales                                 0.576934      0.608224
# eucalyptus                                    0.903182      0.917993
# ilpd                                          0.695953      0.731168
# kc2                                           0.832413      0.830241
# mfeat-fourier                                 0.965515      0.965656
# mfeat-karhunen                                0.991204      0.971571
# mfeat-morphological                           0.959084      0.959097
# mfeat-zernike                                 0.968726      0.968048
# pc1                                           0.838456      0.845385
# pc3                                           0.804156      0.807963
# pc4                                           0.912561      0.916992
# qsar-biodeg                                   0.919956      0.924911
# steel-plates-fault                            0.931383      0.912893
# tic-tac-toe                                   0.997024      0.995356
# vehicle                                       0.941762      0.942815
# wdbc                                          0.995149      0.995241
#
# model                             RandomForest$^\dag$  ResNet$^\ddag$  \
# dataset
# MiceProtein                                  0.999188        0.999957
# analcatdata_authorship                       0.999687        0.999948
# analcatdata_dmft                             0.585847        0.538061
# balance-scale                                0.840023        0.968915
# banknote-authentication                      0.999684        1.000000
# blood-transfusion-service-center             0.721215        0.740112
# breast-w                                     0.990647        0.991983
# car                                          0.994567        0.996065
# climate-model-simulation-crashes             0.871042        0.916895
# cmc                                          0.730262        0.682359
# credit-approval                              0.936817        0.910746
# credit-g                                     0.790219        0.757496
# cylinder-bands                               0.867415        0.834256
# diabetes                                     0.830685        0.831712
# dresses-sales                                0.559420        0.558495
# eucalyptus                                   0.896488        0.888000
# ilpd                                         0.708083        0.697539
# kc2                                          0.826629        0.809644
# mfeat-fourier                                0.980418        0.975564
# mfeat-karhunen                               0.996574        0.998159
# mfeat-morphological                          0.960449        0.966576
# mfeat-zernike                                0.972976        0.981979
# pc1                                          0.840518        0.791535
# pc3                                          0.815730        0.785989
# pc4                                          0.919542        0.878979
# qsar-biodeg                                  0.918911        0.919836
# steel-plates-fault                           0.958753        0.949565
# tic-tac-toe                                  0.984253        0.998178
# vehicle                                      0.922938        0.954699
# wdbc                                         0.989250        0.990586
#
# model                               TabPFN  XGBoost$^\dag$
# dataset
# MiceProtein                       0.999578        0.999776
# analcatdata_authorship            0.999988        0.999920
# analcatdata_dmft                  0.576601        0.570857
# balance-scale                     0.996911        0.990811
# banknote-authentication           1.000000        0.999995
# blood-transfusion-service-center  0.756096        0.736017
# breast-w                          0.993417        0.991548
# car                               0.995364        0.995442
# climate-model-simulation-crashes  0.942607        0.928573
# cmc                               0.726030        0.727905
# credit-approval                   0.931590        0.937455
# credit-g                          0.789666        0.787075
# cylinder-bands                    0.833360        0.885277
# diabetes                          0.840872        0.839053
# dresses-sales                     0.535661        0.585945
# eucalyptus                        0.923970        0.902599
# ilpd                              0.735804        0.710528
# kc2                               0.834560        0.824100
# mfeat-fourier                     0.980081        0.979313
# mfeat-karhunen                    0.997788        0.997947
# mfeat-morphological               0.965225        0.961621
# mfeat-zernike                     0.981262        0.973150
# pc1                               0.874473        0.843660
# pc3                               0.835707        0.823037
# pc4                               0.936102        0.929943
# qsar-biodeg                       0.933658        0.921918
# steel-plates-fault                0.963711        0.964463
# tic-tac-toe                       0.962244        0.997030
# vehicle                           0.958669        0.927204
# wdbc                              0.996465        0.993341

# %%
ranks_test = pivoted_for_cd_test.T.rank(ascending=False).mean(axis=1).rename("rank")
result_table = unnormed_table.merge(normed_table.drop(columns=["inference_time", "fit_time", "inference_time std", "fit_time std"]), left_index=True, right_index=True).merge(ranks_test, left_on="model", right_index=True, how="left").sort_values("rank")

# %%
result_table['fit+predict'] = result_table['fit_time'] + result_table['inference_time']

# %%
pd.set_option("display.float_format", lambda x: f"{x:.3f}")

result_table[['rank', 'Normalized ROC AUC', 'Normalized ROC AUC std', 'ROC AUC', 'ROC AUC std', 'fit_time', 'inference_time', 'fit+predict']]
# Out:
#                              rank  Normalized ROC AUC  Normalized ROC AUC std  \
# model
# TabPFN                      3.733               0.850                   0.026
# MLP-Distill                 4.767               0.802                   0.027
# MotherNet                   5.567               0.780                   0.037
# XGBoost$^\dag$              5.933               0.804                   0.027
# MotherNet NE                6.500               0.716                   0.026
# MLP$^\ddag$                 7.267               0.744                   0.025
# Logistic Regression$^\dag$  7.300               0.749                   0.024
# ResNet$^\ddag$              7.867               0.710                   0.025
# RandomForest$^\dag$         7.900               0.732                   0.020
# MotherNet FT$^\ddag$        7.900               0.708                   0.024
# HyperFast$^\ddag$           7.900               0.729                   0.028
# HyperFast default           8.567               0.681                   0.020
# HyperFast no FT            11.033               0.530                   0.030
# KNN$^\dag$                 12.767               0.455                   0.022
# MotherNet (CPU)               NaN               0.784                   0.017
#
#                             ROC AUC  ROC AUC std  fit_time  inference_time  \
# model
# TabPFN                        0.893        0.003     0.008           0.337
# MLP-Distill                   0.885        0.004     4.382           0.002
# MotherNet                     0.889        0.004     0.136           0.006
# XGBoost$^\dag$                0.891        0.003     4.912           0.024
# MotherNet NE                  0.887        0.003     0.040           0.001
# MLP$^\ddag$                   0.882        0.003     2.257           0.001
# Logistic Regression$^\dag$    0.883        0.002     0.209           0.000
# ResNet$^\ddag$                0.877        0.004     1.668           0.001
# RandomForest$^\dag$           0.880        0.003     0.200           0.032
# MotherNet FT$^\ddag$          0.883        0.004     0.839           0.002
# HyperFast$^\ddag$             0.877        0.004    15.931           0.083
# HyperFast default             0.873        0.002    25.960           0.046
# HyperFast no FT               0.859        0.003     3.792           0.045
# KNN$^\dag$                    0.848        0.003     0.000           0.005
# MotherNet (CPU)               0.890        0.002     7.904           0.107
#
#                             fit+predict
# model
# TabPFN                            0.344
# MLP-Distill                       4.384
# MotherNet                         0.143
# XGBoost$^\dag$                    4.936
# MotherNet NE                      0.040
# MLP$^\ddag$                       2.258
# Logistic Regression$^\dag$        0.209
# ResNet$^\ddag$                    1.669
# RandomForest$^\dag$               0.232
# MotherNet FT$^\ddag$              0.841
# HyperFast$^\ddag$                16.014
# HyperFast default                26.006
# HyperFast no FT                   3.837
# KNN$^\dag$                        0.005
# MotherNet (CPU)                   8.010

# %%
plt.figure(figsize=(8, 8))
for_scatter_plot = result_table.dropna(subset="rank").drop(index=["KNN$^\dag$", "HyperFast no FT", "MotherNet NE"])
#for_scatter_plot = result_table.dropna(subset="rank").drop(index=["KNN$^\dag$"])
for_scatter_plot.plot(x="Normalized ROC AUC", y="fit+predict", kind="scatter", ax=plt.gca())
for  name, row in for_scatter_plot.iterrows():
    plt.text(row["Normalized ROC AUC"], row["fit+predict"], name)
plt.yscale("log")
plt.xlim(0.67, 0.9)
plt.savefig("../figures/time_roc_scatter.pdf", dpi=300, bbox_inches="tight")

# %%
all_times = compare_splits_over_time_test_normalized.groupby(["model", "max_time"]).mean().drop(columns="split").reset_index()
all_times.loc[all_times.max_time == 1, "max_time"] = 0

# %%
all_times.model.unique()
# Out:
# array(['HyperFast default', 'HyperFast no FT', 'HyperFast$^\\ddag$',
#        'KNN$^\\dag$', 'Logistic Regression$^\\dag$', 'MLP$^\\ddag$',
#        'MLP-Distill', 'MotherNet', 'MotherNet (CPU)',
#        'MotherNet FT$^\\ddag$', 'MotherNet NE', 'RandomForest$^\\dag$',
#        'ResNet$^\\ddag$', 'TabPFN', 'XGBoost$^\\dag$'], dtype=object)

# %%
all_times.model = all_times.model.str.replace('HyperFast default', 'HyperFast').replace('HyperFast no FT', 'HyperFast').replace('HyperFast$^\ddag$', 'HyperFast')
all_times = all_times[all_times.model != 'MotherNet (CPU)']

# %%
all_times['total_time'] = all_times.max_time + all_times.fit_time + all_times.inference_time
plt.figure(figsize=(15, 10))
ax = plt.gca()
for model in all_times.model.unique():
    if model == "MotherNet FT$^\ddag$":
        continue
    this_model = all_times[all_times.model == model].sort_values("total_time").reset_index(drop=True)
    if len(this_model) > 1:
        this_model.plot(x="mean_metric", y="total_time", ax=ax, marker="o", legend=False)
    else:
        this_model.plot(x="mean_metric", y="total_time", ax=ax,  marker="o", kind="scatter", c="k")
    print(model)
    if model in ["ResNet$^\ddag$"]:
        plt.text(this_model["mean_metric"].iloc[0] - .04, this_model["total_time"].iloc[0], model)
    else:
        plt.text(this_model["mean_metric"].iloc[0], this_model["total_time"].iloc[0], model)

plt.yscale("log")
plt.xlim(0.44, 0.95)
plt.ylabel("Duration Fit + Predict + Tuning (s)")
plt.xlabel("Mean normalized ROC AUC")
# Out:
# HyperFast
# KNN$^\dag$
# Logistic Regression$^\dag$
# MLP$^\ddag$
# MLP-Distill
# MotherNet
# MotherNet NE
# RandomForest$^\dag$
# ResNet$^\ddag$
# TabPFN
# XGBoost$^\dag$
# Text(0.5, 0, 'Mean normalized ROC AUC')

# %%
result_table
# Out:
#                             fit_time  inference_time  ROC AUC  fit_time std  \
# model
# TabPFN                         0.008           0.337    0.893         0.016
# MLP-Distill                    4.382           0.002    0.885         0.042
# MotherNet                      0.136           0.006    0.889         0.029
# XGBoost$^\dag$                 8.270           0.032    0.885         6.404
# MotherNet NE                   0.040           0.001    0.887         0.007
# MLP$^\ddag$                    2.257           0.001    0.882         0.225
# Logistic Regression$^\dag$     0.177           0.001    0.882         0.045
# ResNet$^\ddag$                 1.668           0.001    0.877         0.265
# RandomForest$^\dag$            0.278           0.041    0.878         0.047
# MotherNet FT$^\ddag$           0.839           0.002    0.883         0.122
# HyperFast$^\ddag$             15.931           0.083    0.877         4.749
# HyperFast default             25.960           0.046    0.873         0.037
# HyperFast no FT                3.792           0.045    0.859         0.018
# KNN$^\dag$                     0.000           0.007    0.848         0.000
# MotherNet (CPU)                7.904           0.107    0.890         0.061
#
#                             inference_time std  ROC AUC std  \
# model
# TabPFN                                   0.001        0.003
# MLP-Distill                              0.000        0.004
# MotherNet                                0.000        0.004
# XGBoost$^\dag$                           0.026        0.006
# MotherNet NE                             0.000        0.003
# MLP$^\ddag$                              0.000        0.003
# Logistic Regression$^\dag$               0.001        0.003
# ResNet$^\ddag$                           0.000        0.004
# RandomForest$^\dag$                      0.007        0.003
# MotherNet FT$^\ddag$                     0.000        0.004
# HyperFast$^\ddag$                        0.025        0.004
# HyperFast default                        0.000        0.002
# HyperFast no FT                          0.000        0.003
# KNN$^\dag$                               0.003        0.003
# MotherNet (CPU)                          0.002        0.002
#
#                             Normalized ROC AUC  Normalized ROC AUC std   rank  \
# model
# TabPFN                                   0.850                   0.026  3.733
# MLP-Distill                              0.802                   0.027  4.767
# MotherNet                                0.780                   0.037  5.567
# XGBoost$^\dag$                           0.757                   0.046  5.933
# MotherNet NE                             0.716                   0.026  6.500
# MLP$^\ddag$                              0.744                   0.025  7.267
# Logistic Regression$^\dag$               0.734                   0.034  7.300
# ResNet$^\ddag$                           0.710                   0.025  7.867
# RandomForest$^\dag$                      0.715                   0.030  7.900
# MotherNet FT$^\ddag$                     0.708                   0.024  7.900
# HyperFast$^\ddag$                        0.729                   0.028  7.900
# HyperFast default                        0.681                   0.020  8.567
# HyperFast no FT                          0.530                   0.030 11.033
# KNN$^\dag$                               0.453                   0.021 12.767
# MotherNet (CPU)                          0.784                   0.017    NaN
#
#                             fit+predict
# model
# TabPFN                            0.344
# MLP-Distill                       4.384
# MotherNet                         0.143
# XGBoost$^\dag$                    8.301
# MotherNet NE                      0.040
# MLP$^\ddag$                       2.258
# Logistic Regression$^\dag$        0.178
# ResNet$^\ddag$                    1.669
# RandomForest$^\dag$               0.319
# MotherNet FT$^\ddag$              0.841
# HyperFast$^\ddag$                16.014
# HyperFast default                26.006
# HyperFast no FT                   3.837
# KNN$^\dag$                        0.008
# MotherNet (CPU)                   8.010

# %%
plt.figure(figsize=(8, 8))
for_scatter_plot = result_table.dropna(subset="rank").drop(index=["KNN$^\dag$", "HyperFast no FT", "MotherNet NE"])
#for_scatter_plot = result_table.dropna(subset="rank").drop(index=["KNN$^\dag$"])
for_scatter_plot.plot(x="Normalized ROC AUC", y="fit+predict", kind="scatter", ax=plt.gca())
for  name, row in for_scatter_plot.iterrows():
    plt.text(row["Normalized ROC AUC"], row["fit+predict"], name)
plt.yscale("log")
plt.xlim(0.67, 0.9)
plt.savefig("../figures/time_roc_scatter.pdf", dpi=300, bbox_inches="tight")

# %%
def fmt(x):
    return f"{x:.3f}"

# %%
for_paper = result_table[['rank', 'Normalized ROC AUC', 'Normalized ROC AUC std', 'ROC AUC', 'ROC AUC std', 'fit_time', 'inference_time', "fit+predict"]].copy()
for_paper['Normalized ROC AUC'] = for_paper['Normalized ROC AUC'].apply(fmt) + "$\pm$" + for_paper['Normalized ROC AUC std'].apply(fmt)
for_paper['ROC AUC'] = for_paper['ROC AUC'].apply(fmt) + "$\pm$" + for_paper['ROC AUC std'].apply(fmt)
for_paper = for_paper.drop(columns=['Normalized ROC AUC std', 'ROC AUC std'])
for_paper.columns = ['rank', 'normalized AUC', 'AUC', 'fit time', 'predict time', "fit + predict" ]
print(for_paper.to_latex(float_format="%.3f"))
# Out:
# \begin{tabular}{lrllrrr}
# \toprule
#  & rank & normalized AUC & AUC & fit time & predict time & fit + predict \\
# model &  &  &  &  &  &  \\
# \midrule
# TabPFN & 3.733 & 0.850$\pm$0.026 & 0.893$\pm$0.003 & 0.008 & 0.337 & 0.344 \\
# MLP-Distill & 4.767 & 0.802$\pm$0.027 & 0.885$\pm$0.004 & 4.382 & 0.002 & 4.384 \\
# MotherNet & 5.567 & 0.780$\pm$0.037 & 0.889$\pm$0.004 & 0.136 & 0.006 & 0.143 \\
# XGBoost$^\dag$ & 5.933 & 0.757$\pm$0.046 & 0.885$\pm$0.006 & 8.270 & 0.032 & 8.301 \\
# MotherNet NE & 6.500 & 0.716$\pm$0.026 & 0.887$\pm$0.003 & 0.040 & 0.001 & 0.040 \\
# MLP$^\ddag$ & 7.267 & 0.744$\pm$0.025 & 0.882$\pm$0.003 & 2.257 & 0.001 & 2.258 \\
# Logistic Regression$^\dag$ & 7.300 & 0.734$\pm$0.034 & 0.882$\pm$0.003 & 0.177 & 0.001 & 0.178 \\
# ResNet$^\ddag$ & 7.867 & 0.710$\pm$0.025 & 0.877$\pm$0.004 & 1.668 & 0.001 & 1.669 \\
# RandomForest$^\dag$ & 7.900 & 0.715$\pm$0.030 & 0.878$\pm$0.003 & 0.278 & 0.041 & 0.319 \\
# MotherNet FT$^\ddag$ & 7.900 & 0.708$\pm$0.024 & 0.883$\pm$0.004 & 0.839 & 0.002 & 0.841 \\
# HyperFast$^\ddag$ & 7.900 & 0.729$\pm$0.028 & 0.877$\pm$0.004 & 15.931 & 0.083 & 16.014 \\
# HyperFast default & 8.567 & 0.681$\pm$0.020 & 0.873$\pm$0.002 & 25.960 & 0.046 & 26.006 \\
# HyperFast no FT & 11.033 & 0.530$\pm$0.030 & 0.859$\pm$0.003 & 3.792 & 0.045 & 3.837 \\
# KNN$^\dag$ & 12.767 & 0.453$\pm$0.021 & 0.848$\pm$0.003 & 0.000 & 0.007 & 0.008 \\
# MotherNet (CPU) & NaN & 0.784$\pm$0.017 & 0.890$\pm$0.002 & 7.904 & 0.107 & 8.010 \\
# \bottomrule
# \end{tabular}

# %%
# plt.figure(figsize=(4, 3), dpi=300)

# compare_splits_varies = compare_splits_over_time_valid_normalized[compare_splits_over_time_valid_normalized.model.isin(varies_over_time)]
# compare_splits_fixed = compare_splits_over_time_valid_normalized[~compare_splits_over_time_valid_normalized.model.isin(varies_over_time)]


# ax = sns.lineplot(data=compare_splits_varies, x="max_time", y="mean_metric", hue="model",  marker="o", palette=color_mapping)

# compare_splits_fixed_dummy = compare_splits_over_time_valid_normalized.copy()
# compare_splits_fixed_dummy['max_time'] = compare_splits_varies.max_time.max()
# sns.lineplot(data=pd.concat([compare_splits_fixed, compare_splits_fixed_dummy]),
#               x="max_time", y="mean_metric", hue="model", ax=ax, palette=color_mapping)
# plt.xscale("log")
# #legend = plt.legend(loc=(1.1 , .3))
# legend = ax.get_legend()
# legend.remove()
# #ax.set_ylim(0.85, 0.90)
# ax.set_ylabel("mean ROC AUC")
# ax.set_xlabel("max time (s)")
# plt.savefig("../figures/mean_auc_over_time_valid_normalized.pdf", bbox_inches="tight")

# %%
sns.clustermap((pivoted_for_cd_test.T - pivoted_for_cd_test.T.mean()), figsize=(20, 10))

# %%
print(pivoted_for_cd_test.to_latex(float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrr}
# \toprule
# model & HyperFast default & HyperFast no FT & HyperFast$^\ddag$ & KNN$^\dag$ & Logistic Regression$^\dag$ & MLP$^\ddag$ & MLP-Distill & MotherNet & MotherNet FT$^\ddag$ & MotherNet NE & RandomForest$^\dag$ & ResNet$^\ddag$ & TabPFN & XGBoost$^\dag$ \\
# dataset &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# MiceProtein & 1.00 & 0.99 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 \\
# analcatdata_authorship & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 \\
# analcatdata_dmft & 0.53 & 0.55 & 0.56 & 0.55 & 0.57 & 0.57 & 0.58 & 0.57 & 0.55 & 0.56 & 0.59 & 0.54 & 0.58 & 0.57 \\
# balance-scale & 0.99 & 0.89 & 0.99 & 0.89 & 0.96 & 0.99 & 0.99 & 1.00 & 0.99 & 0.99 & 0.84 & 0.97 & 1.00 & 0.99 \\
# banknote-authentication & 1.00 & 0.98 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 \\
# blood-transfusion-service-center & 0.71 & 0.74 & 0.73 & 0.71 & 0.75 & 0.73 & 0.76 & 0.76 & 0.76 & 0.76 & 0.72 & 0.74 & 0.76 & 0.74 \\
# breast-w & 0.99 & 0.99 & 0.99 & 0.98 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 \\
# car & 0.99 & 0.92 & 0.99 & 0.92 & 0.98 & 1.00 & 0.99 & 0.97 & 0.98 & 0.97 & 0.99 & 1.00 & 1.00 & 1.00 \\
# climate-model-simulation-crashes & 0.91 & 0.91 & 0.90 & 0.85 & 0.93 & 0.91 & 0.91 & 0.95 & 0.93 & 0.94 & 0.87 & 0.92 & 0.94 & 0.93 \\
# cmc & 0.67 & 0.67 & 0.69 & 0.63 & 0.68 & 0.67 & 0.74 & 0.72 & 0.71 & 0.72 & 0.73 & 0.68 & 0.73 & 0.73 \\
# credit-approval & 0.90 & 0.92 & 0.93 & 0.91 & 0.92 & 0.92 & 0.93 & 0.93 & 0.93 & 0.93 & 0.94 & 0.91 & 0.93 & 0.94 \\
# credit-g & 0.75 & 0.77 & 0.76 & 0.73 & 0.77 & 0.76 & 0.77 & 0.79 & 0.79 & 0.79 & 0.79 & 0.76 & 0.79 & 0.79 \\
# cylinder-bands & 0.82 & 0.80 & 0.81 & 0.78 & 0.82 & 0.84 & 0.81 & 0.80 & 0.80 & 0.83 & 0.87 & 0.83 & 0.83 & 0.89 \\
# diabetes & 0.80 & 0.82 & 0.81 & 0.81 & 0.84 & 0.84 & 0.84 & 0.85 & 0.83 & 0.84 & 0.83 & 0.83 & 0.84 & 0.84 \\
# dresses-sales & 0.55 & 0.58 & 0.55 & 0.56 & 0.57 & 0.57 & 0.54 & 0.57 & 0.58 & 0.61 & 0.56 & 0.56 & 0.54 & 0.59 \\
# eucalyptus & 0.87 & 0.81 & 0.87 & 0.80 & 0.90 & 0.89 & 0.92 & 0.92 & 0.90 & 0.92 & 0.90 & 0.89 & 0.92 & 0.90 \\
# ilpd & 0.71 & 0.72 & 0.70 & 0.65 & 0.74 & 0.73 & 0.73 & 0.73 & 0.70 & 0.73 & 0.71 & 0.70 & 0.74 & 0.71 \\
# kc2 & 0.74 & 0.81 & 0.80 & 0.78 & 0.83 & 0.81 & 0.84 & 0.83 & 0.83 & 0.83 & 0.83 & 0.81 & 0.83 & 0.82 \\
# mfeat-fourier & 0.98 & 0.96 & 0.98 & 0.97 & 0.98 & 0.97 & 0.98 & 0.97 & 0.97 & 0.97 & 0.98 & 0.98 & 0.98 & 0.98 \\
# mfeat-karhunen & 1.00 & 1.00 & 1.00 & 0.99 & 1.00 & 1.00 & 1.00 & 0.99 & 0.99 & 0.97 & 1.00 & 1.00 & 1.00 & 1.00 \\
# mfeat-morphological & 0.97 & 0.96 & 0.97 & 0.95 & 0.97 & 0.97 & 0.97 & 0.96 & 0.96 & 0.96 & 0.96 & 0.97 & 0.97 & 0.96 \\
# mfeat-zernike & 0.98 & 0.97 & 0.98 & 0.98 & 0.98 & 0.98 & 0.98 & 0.98 & 0.97 & 0.97 & 0.97 & 0.98 & 0.98 & 0.97 \\
# pc1 & 0.82 & 0.78 & 0.82 & 0.78 & 0.83 & 0.80 & 0.85 & 0.84 & 0.84 & 0.85 & 0.84 & 0.79 & 0.87 & 0.84 \\
# pc3 & 0.79 & 0.79 & 0.82 & 0.75 & 0.79 & 0.80 & 0.83 & 0.81 & 0.80 & 0.81 & 0.82 & 0.79 & 0.84 & 0.82 \\
# pc4 & 0.90 & 0.86 & 0.90 & 0.82 & 0.89 & 0.90 & 0.93 & 0.93 & 0.91 & 0.92 & 0.92 & 0.88 & 0.94 & 0.93 \\
# qsar-biodeg & 0.92 & 0.90 & 0.92 & 0.89 & 0.92 & 0.92 & 0.92 & 0.93 & 0.92 & 0.92 & 0.92 & 0.92 & 0.93 & 0.92 \\
# steel-plates-fault & 0.96 & 0.94 & 0.95 & 0.92 & 0.94 & 0.95 & 0.96 & 0.93 & 0.93 & 0.91 & 0.96 & 0.95 & 0.96 & 0.96 \\
# tic-tac-toe & 0.99 & 0.81 & 0.92 & 0.99 & 1.00 & 1.00 & 0.85 & 1.00 & 1.00 & 1.00 & 0.98 & 1.00 & 0.96 & 1.00 \\
# vehicle & 0.95 & 0.91 & 0.95 & 0.88 & 0.95 & 0.96 & 0.96 & 0.95 & 0.94 & 0.94 & 0.92 & 0.95 & 0.96 & 0.93 \\
# wdbc & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 0.99 & 1.00 & 1.00 & 1.00 & 0.99 & 0.99 & 1.00 & 0.99 \\
# \bottomrule
# \end{tabular}

# %%
((pivoted_for_cd_test.T - pivoted_for_cd_test.T.min()) / (pivoted_for_cd_test.T.max() - pivoted_for_cd_test.T.min())).T
# Out:
# model                             HyperFast default  HyperFast no FT  \
# dataset
# MiceProtein                                   1.000            0.000
# analcatdata_authorship                        0.805            0.813
# analcatdata_dmft                              0.000            0.468
# balance-scale                                 0.972            0.291
# banknote-authentication                       1.000            0.000
# blood-transfusion-service-center              0.127            0.597
# breast-w                                      0.777            0.775
# car                                           0.985            0.066
# climate-model-simulation-crashes              0.608            0.666
# cmc                                           0.313            0.384
# credit-approval                               0.000            0.668
# credit-g                                      0.354            0.701
# cylinder-bands                                0.333            0.194
# diabetes                                      0.000            0.466
# dresses-sales                                 0.266            0.566
# eucalyptus                                    0.597            0.068
# ilpd                                          0.694            0.806
# kc2                                           0.000            0.742
# mfeat-fourier                                 0.762            0.000
# mfeat-karhunen                                0.990            0.889
# mfeat-morphological                           0.985            0.366
# mfeat-zernike                                 0.808            0.327
# pc1                                           0.448            0.000
# pc3                                           0.501            0.494
# pc4                                           0.701            0.369
# qsar-biodeg                                   0.764            0.291
# steel-plates-fault                            0.821            0.607
# tic-tac-toe                                   0.965            0.000
# vehicle                                       0.914            0.349
# wdbc                                          0.819            0.000
#
# model                             HyperFast$^\ddag$  KNN$^\dag$  \
# dataset
# MiceProtein                                   1.000       0.752
# analcatdata_authorship                        0.801       0.250
# analcatdata_dmft                              0.577       0.336
# balance-scale                                 0.974       0.287
# banknote-authentication                       1.000       0.950
# blood-transfusion-service-center              0.463       0.000
# breast-w                                      0.612       0.000
# car                                           0.926       0.000
# climate-model-simulation-crashes              0.554       0.000
# cmc                                           0.578       0.000
# credit-approval                               0.690       0.388
# credit-g                                      0.514       0.000
# cylinder-bands                                0.303       0.000
# diabetes                                      0.332       0.206
# dresses-sales                                 0.225       0.270
# eucalyptus                                    0.602       0.000
# ilpd                                          0.588       0.000
# kc2                                           0.653       0.453
# mfeat-fourier                                 0.779       0.400
# mfeat-karhunen                                0.995       0.835
# mfeat-morphological                           0.963       0.000
# mfeat-zernike                                 1.000       0.560
# pc1                                           0.450       0.012
# pc3                                           0.763       0.000
# pc4                                           0.657       0.000
# qsar-biodeg                                   0.791       0.000
# steel-plates-fault                            0.806       0.138
# tic-tac-toe                                   0.597       0.939
# vehicle                                       0.913       0.000
# wdbc                                          0.732       0.303
#
# model                             Logistic Regression$^\dag$  MLP$^\ddag$  \
# dataset
# MiceProtein                                            0.936        0.976
# analcatdata_authorship                                 0.916        0.851
# analcatdata_dmft                                       0.723        0.679
# balance-scale                                          0.777        0.984
# banknote-authentication                                0.983        1.000
# blood-transfusion-service-center                       0.805        0.490
# breast-w                                               0.960        0.765
# car                                                    0.832        0.996
# climate-model-simulation-crashes                       0.850        0.659
# cmc                                                    0.471        0.362
# credit-approval                                        0.531        0.476
# credit-g                                               0.646        0.595
# cylinder-bands                                         0.385        0.575
# diabetes                                               0.844        0.901
# dresses-sales                                          0.519        0.420
# eucalyptus                                             0.778        0.746
# ilpd                                                   1.000        0.914
# kc2                                                    0.880        0.756
# mfeat-fourier                                          0.804        0.657
# mfeat-karhunen                                         0.900        0.912
# mfeat-morphological                                    0.895        0.887
# mfeat-zernike                                          0.812        0.911
# pc1                                                    0.564        0.179
# pc3                                                    0.391        0.575
# pc4                                                    0.629        0.644
# qsar-biodeg                                            0.728        0.681
# steel-plates-fault                                     0.486        0.725
# tic-tac-toe                                            0.987        0.987
# vehicle                                                0.806        0.945
# wdbc                                                   0.657        0.292
#
# model                             MLP-Distill  MotherNet  \
# dataset
# MiceProtein                             0.984      0.857
# analcatdata_authorship                  0.955      1.000
# analcatdata_dmft                        0.847      0.744
# balance-scale                           0.970      0.999
# banknote-authentication                 1.000      1.000
# blood-transfusion-service-center        0.945      0.965
# breast-w                                1.000      0.908
# car                                     0.863      0.617
# climate-model-simulation-crashes        0.635      1.000
# cmc                                     1.000      0.877
# credit-approval                         0.756      0.757
# credit-g                                0.745      1.000
# cylinder-bands                          0.283      0.165
# diabetes                                0.904      1.000
# dresses-sales                           0.004      0.478
# eucalyptus                              0.950      0.994
# ilpd                                    0.911      0.891
# kc2                                     1.000      0.918
# mfeat-fourier                           1.000      0.530
# mfeat-karhunen                          0.984      0.844
# mfeat-morphological                     1.000      0.565
# mfeat-zernike                           0.898      0.575
# pc1                                     0.775      0.675
# pc3                                     0.948      0.739
# pc4                                     0.968      0.960
# qsar-biodeg                             0.763      0.816
# steel-plates-fault                      0.830      0.377
# tic-tac-toe                             0.208      0.986
# vehicle                                 1.000      0.845
# wdbc                                    0.764      0.862
#
# model                             MotherNet FT$^\ddag$  MotherNet NE  \
# dataset
# MiceProtein                                      0.575         0.684
# analcatdata_authorship                           0.845         0.862
# analcatdata_dmft                                 0.342         0.553
# balance-scale                                    0.977         0.980
# banknote-authentication                          1.000         1.000
# blood-transfusion-service-center                 0.963         1.000
# breast-w                                         0.942         0.919
# car                                              0.761         0.666
# climate-model-simulation-crashes                 0.873         0.963
# cmc                                              0.729         0.804
# credit-approval                                  0.721         0.769
# credit-g                                         0.932         0.930
# cylinder-bands                                   0.209         0.490
# diabetes                                         0.685         0.898
# dresses-sales                                    0.569         1.000
# eucalyptus                                       0.835         0.952
# ilpd                                             0.536         0.913
# kc2                                              0.938         0.917
# mfeat-fourier                                    0.140         0.148
# mfeat-karhunen                                   0.738         0.000
# mfeat-morphological                              0.495         0.496
# mfeat-zernike                                    0.047         0.000
# pc1                                              0.606         0.682
# pc3                                              0.620         0.665
# pc4                                              0.794         0.833
# qsar-biodeg                                      0.674         0.792
# steel-plates-fault                               0.359         0.000
# tic-tac-toe                                      0.994         0.985
# vehicle                                          0.761         0.774
# wdbc                                             0.839         0.850
#
# model                             RandomForest$^\dag$  ResNet$^\ddag$  TabPFN  \
# dataset
# MiceProtein                                     0.930           0.998   0.965
# analcatdata_authorship                          0.000           0.860   0.992
# analcatdata_dmft                                1.000           0.190   0.843
# balance-scale                                   0.000           0.822   1.000
# banknote-authentication                         0.980           1.000   1.000
# blood-transfusion-service-center                0.248           0.615   0.926
# breast-w                                        0.641           0.770   0.909
# car                                             0.981           1.000   0.991
# climate-model-simulation-crashes                0.228           0.694   0.955
# cmc                                             0.950           0.479   0.908
# credit-approval                                 0.983           0.295   0.845
# credit-g                                        0.982           0.480   0.973
# cylinder-bands                                  0.829           0.510   0.502
# diabetes                                        0.676           0.695   0.870
# dresses-sales                                   0.327           0.315   0.000
# eucalyptus                                      0.781           0.714   1.000
# ilpd                                            0.666           0.553   0.963
# kc2                                             0.882           0.718   0.958
# mfeat-fourier                                   0.984           0.709   0.964
# mfeat-karhunen                                  0.940           1.000   0.986
# mfeat-morphological                             0.579           0.953   0.871
# mfeat-zernike                                   0.345           0.976   0.925
# pc1                                             0.629           0.093   1.000
# pc3                                             0.759           0.401   1.000
# pc4                                             0.855           0.500   1.000
# qsar-biodeg                                     0.650           0.672   1.000
# steel-plates-fault                              0.889           0.711   0.985
# tic-tac-toe                                     0.927           1.000   0.812
# vehicle                                         0.526           0.922   0.972
# wdbc                                            0.116           0.280   1.000
#
# model                             XGBoost$^\dag$
# dataset
# MiceProtein                                0.982
# analcatdata_authorship                     0.768
# analcatdata_dmft                           0.746
# balance-scale                              0.961
# banknote-authentication                    1.000
# blood-transfusion-service-center           0.536
# breast-w                                   0.728
# car                                        0.992
# climate-model-simulation-crashes           0.813
# cmc                                        0.927
# credit-approval                            1.000
# credit-g                                   0.933
# cylinder-bands                             1.000
# diabetes                                   0.835
# dresses-sales                              0.693
# eucalyptus                                 0.830
# ilpd                                       0.692
# kc2                                        0.858
# mfeat-fourier                              0.921
# mfeat-karhunen                             0.992
# mfeat-morphological                        0.650
# mfeat-zernike                              0.357
# pc1                                        0.663
# pc3                                        0.847
# pc4                                        0.946
# qsar-biodeg                                0.721
# steel-plates-fault                         1.000
# tic-tac-toe                                0.994
# vehicle                                    0.579
# wdbc                                       0.617
